# %% [markdown]
# #### Print Function

# %%
print("Hello world!");
# Out:
# Hello world!

# %% [markdown]
# #### Comment

# %%
# Select and press Ctrl + Forward salsh to comment multiple line

print("below are single linecommmented lines");
# print("hi");
# print("hi");
# print("hi");
# print("hi");

print("below are multiline comment example");

'''
this is multiline comment
'''
# Out:
# below are single linecommmented lines
# below are multiline comment example
# '\nthis is multiline comment\n'

# %% [markdown]
# #### Variable

# %%
a=3; 
print(a) ;
# Out:
# 3

# %%
b=34;
print(b);
# Out:
# 34

# %%
print(a);
print(b);
# Out:
# 3
# 34

# %%
print(type(a));
# Out:
# <class 'int'>

# %%
c=4.3;
print(c);
# Out:
# 4.3

# %%
print(type(c));
# Out:
# <class 'float'>

# %%
d=False;
print(d);
# Out:
# False

# %%
d=4;

# %%
print(d);
# Out:
# 4

# %%
print(type(d));
# Out:
# <class 'int'>

# %%
name='Kareem';
print(name);
# Out:
# Kareem

# %%
n=None;
print(n);
# Out:
# None

# %%
print(type(n));
# Out:
# <class 'NoneType'>

# %% [markdown]
# #### String fucntions in python

# %% [markdown]
# #### len(Stiring);

# %%
string='islamia college peshawar ';
print(len(string));
# Out:
# 25

# %% [markdown]
# #### str(argument);

# %%
a =1913;
print(string+str(a));
# Out:
# islamia college peshawar 1913

# %% [markdown]
# #### title();

# %%
print(string.title());
# Out:
# Islamia College Peshawar

# %% [markdown]
# #### lower();

# %%
print("ABBAS".lower());
# Out:
# abbas

# %% [markdown]
# #### upper();

# %%
print(string.upper());
# Out:
# ISLAMIA COLLEGE PESHAWAR

# %% [markdown]
# #### caitalize();;

# %%
print(string.capitalize());
# Out:
# Islamia college peshawar

# %% [markdown]
# #### len(Stiring);

# %%
print(string.replace('islamia','I'));
# Out:
# I college peshawar

# %%
print(string);
# Out:
# islamia college peshawar

# %% [markdown]
# #### split();

# %%
my_list=string.split(' ');
print(my_list);
# Out:
# ['islamia', 'college', 'peshawar', '']

# %%
print(string);
# Out:
# islamia college peshawar

# %%
print('  abbas khan  '.split());
# Out:
# ['abbas', 'khan']

# %%
fruit_string="apple,banana,graps,orange,guava";
fruit_list=fruit_string.split(',');
#print(fruit_list);
fruit_list
# Out:
# ['apple', 'banana', 'graps', 'orange', 'guava']

# %% [markdown]
# #### join(list);

# %%
string2=' '.join(my_list);
print(string2);
# Out:
# islamia college peshawar

# %%
print(string);
print(string2);
# Out:
# islamia college peshawar
# islamia college peshawar

# %%
print(my_list);
# Out:
# ['islamia', 'college', 'peshawar', '']

# %% [markdown]
# #### strip();

# %%
print('  abbas khan  '.strip());
# Out:
# abbas khan

# %%
print(' abbas khan '.rstrip());
# Out:
#  abbas khan

# %%
print('  abbas khan'.lstrip());
# Out:
# abbas khan

# %% [markdown]
# #### Arithmatic Operators

# %%
num1=23;
num2=12;
print("num1 + num2 : ",num1+num2);
print("num1 - num2 : ",num1-num2);
print("num1 * num2 : ",num1*num2);
print("num1 / num2 : ",num1/num2);
# Out:
# num1 + num2 :  35
# num1 - num2 :  11
# num1 * num2 :  276
# num1 / num2 :  1.9166666666666667
