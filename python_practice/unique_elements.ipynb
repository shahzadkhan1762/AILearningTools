# %%
def unique():
    list_string=input("Enter a List : ");
    List=list_string.split(',');
    List=[int(item) for item in List];
    return (set(List));
# Out:
# Enter a List : 34,6234,23,523,323

# %%
unique_list=unique();
# Out:
# Enter a List : 2,5,5,6,7,8,8,9,10,10

# %%
unique_list
# Out:
# {2, 5, 6, 7, 8, 9, 10}
