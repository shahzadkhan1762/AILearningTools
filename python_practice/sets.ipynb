# %% [markdown]
# #### Sets

# %%
# Sets do not allow doplicates
# sets have no indixing/slicing
# Sets donot allow mutable datatype
# set iself is mutable

# %%
S1={3,7,2,8,4,7};

# %%
type(S1)
# Out:
# set

# %%
S2={};

# %%
type(S2)
# Out:
# dict

# %%
S2=set();

# %%
type(S2)
# Out:
# set

# %%
S1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 S1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
for i in S1:
    print(i);
# Out:
# 2
# 3
# 4
# 7
# 8

# %%
sorted(S1)
# Out:
# [2, 3, 4, 7, 8]

# %%
sorted(S1, reverse=True)
# Out:
# [8, 7, 4, 3, 2]

# %%
S1
# Out:
# {2, 3, 4, 7, 8}

# %%
min(S1)
# Out:
# 2

# %%
max(S1)
# Out:
# 8

# %%
sum(S1)
# Out:
# 24

# %%
S2={34,6,23,63,53}

# %%
S2
# Out:
# {6, 23, 34, 53, 63}

# %%
S1
# Out:
# {2, 3, 4, 7, 8}

# %%
S1+S2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 S1+S2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
S1*S2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 S1*S2
#
# TypeError: unsupported operand type(s) for *: 'set' and 'set'

# %%
S1.add(9);

# %%
S1
# Out:
# {2, 3, 4, 7, 8, 9}

# %%
S1.union(S2)
# Out:
# {2, 3, 4, 6, 7, 8, 9, 23, 34, 53, 63}

# %%
S1.intersection(S2)
# Out:
# set()

# %%
S2.add(4)

# %%
S1.intersection(S2)
# Out:
# {4}

# %%
S1.difference(S2)
# Out:
# {2, 3, 7, 8, 9}

# %%
S2.difference(S1)
# Out:
# {6, 23, 34, 53, 63}

# %%
S1.symmetric_difference(S2)
# Out:
# {2, 3, 6, 7, 8, 9, 23, 34, 53, 63}

# %%
S3=S1.symmetric_difference(S2);

# %%
S3
# Out:
# {2, 3, 6, 7, 8, 9, 23, 34, 53, 63}

# %%
S2
# Out:
# {4, 6, 23, 34, 53, 63}

# %%
S2.remove(4)

# %%
S2
# Out:
# {6, 23, 34, 53, 63}

# %%
S1.isdisjoint(S2)
# Out:
# True

# %%
S2.isdisjoint(S1)
# Out:
# True

# %%
S1.issubset(S2)
# Out:
# False

# %%
S2.issubset(S1)
# Out:
# False

# %%
S3.issuperset(S1)
# Out:
# False

# %%
S3.issuperset(S2)
# Out:
# True
