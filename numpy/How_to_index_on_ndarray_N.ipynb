# %%
import numpy as np;

# %%
arr=np.random.randint(low=0,high=100,size=(4,4,5))

# %%
arr
# Out:
# array([[[39, 96,  6, 45, 40],
#         [27,  5, 13, 52, 34],
#         [69, 57, 29, 45, 75],
#         [26, 58, 29,  2, 47]],
#
#        [[82, 36, 55, 86, 55],
#         [68, 72, 64, 54, 97],
#         [ 8, 25, 17, 85, 18],
#         [81,  5, 22, 15, 32]],
#
#        [[41,  6,  9, 51, 25],
#         [ 9, 98, 72, 45,  0],
#         [41, 15, 87, 63, 98],
#         [47, 48, 86, 52, 97]],
#
#        [[25, 71, 76, 48, 41],
#         [52,  1, 30, 30, 83],
#         [30, 64, 84, 44, 67],
#         [12,  2, 84, 71, 93]]])

# %%
arr[0,2:4]
# Out:
# array([[69, 57, 29, 45, 75],
#        [26, 58, 29,  2, 47]])

# %%
arr[np.newaxis,0,2:4]
# Out:
# array([[[69, 57, 29, 45, 75],
#         [26, 58, 29,  2, 47]]])

# %%
arr[0,np.newaxis,2:4]
# Out:
# array([[[69, 57, 29, 45, 75],
#         [26, 58, 29,  2, 47]]])

# %%
arr[0,2:4,np.newaxis]
# Out:
# array([[[69, 57, 29, 45, 75]],
#
#        [[26, 58, 29,  2, 47]]])

# %%
arr[0,2:4,np.newaxis].shape
# Out:
# (2, 1, 5)

# %%
arr[0,2:4,np.newaxis,np.newaxis]
# Out:
# array([[[[69, 57, 29, 45, 75]]],
#
#
#        [[[26, 58, 29,  2, 47]]]])

# %%
arr[(slice(1,2,1),slice(2,5,1))]
# Out:
# array([[[ 8, 25, 17, 85, 18],
#         [81,  5, 22, 15, 32]]])

# %%
arr
# Out:
# array([[[39, 96,  6, 45, 40],
#         [27,  5, 13, 52, 34],
#         [69, 57, 29, 45, 75],
#         [26, 58, 29,  2, 47]],
#
#        [[82, 36, 55, 86, 55],
#         [68, 72, 64, 54, 97],
#         [ 8, 25, 17, 85, 18],
#         [81,  5, 22, 15, 32]],
#
#        [[41,  6,  9, 51, 25],
#         [ 9, 98, 72, 45,  0],
#         [41, 15, 87, 63, 98],
#         [47, 48, 86, 52, 97]],
#
#        [[25, 71, 76, 48, 41],
#         [52,  1, 30, 30, 83],
#         [30, 64, 84, 44, 67],
#         [12,  2, 84, 71, 93]]])

# %%
a=arr[0,0]

# %%
a
# Out:
# array([100,  96,   6,  45,  40])

# %%
a[:]=[11,22,33,44,55]

# %%
a
# Out:
# array([11, 22, 33, 44, 55])

# %%
arr
# Out:
# array([[[11, 22, 33, 44, 55],
#         [27,  5, 13, 52, 34],
#         [69, 57, 29, 45, 75],
#         [26, 58, 29,  2, 47]],
#
#        [[82, 36, 55, 86, 55],
#         [68, 72, 64, 54, 97],
#         [ 8, 25, 17, 85, 18],
#         [81,  5, 22, 15, 32]],
#
#        [[41,  6,  9, 51, 25],
#         [ 9, 98, 72, 45,  0],
#         [41, 15, 87, 63, 98],
#         [47, 48, 86, 52, 97]],
#
#        [[25, 71, 76, 48, 41],
#         [52,  1, 30, 30, 83],
#         [30, 64, 84, 44, 67],
#         [12,  2, 84, 71, 93]]])

# %%
arr1=arr[np.array([0,1]),np.array([2,2])]

# %%
arr1
# Out:
# array([[69, 57, 29, 45, 75],
#        [ 8, 25, 17, 85, 18]])

# %%
arr1[1]=np.arange(5)

# %%
arr1
# Out:
# array([[69, 57, 29, 45, 75],
#        [ 0,  1,  2,  3,  4]])

# %%
arr
# Out:
# array([[[11, 22, 33, 44, 55],
#         [27,  5, 13, 52, 34],
#         [69, 57, 29, 45, 75],
#         [26, 58, 29,  2, 47]],
#
#        [[82, 36, 55, 86, 55],
#         [68, 72, 64, 54, 97],
#         [ 8, 25, 17, 85, 18],
#         [81,  5, 22, 15, 32]],
#
#        [[41,  6,  9, 51, 25],
#         [ 9, 98, 72, 45,  0],
#         [41, 15, 87, 63, 98],
#         [47, 48, 86, 52, 97]],
#
#        [[25, 71, 76, 48, 41],
#         [52,  1, 30, 30, 83],
#         [30, 64, 84, 44, 67],
#         [12,  2, 84, 71, 93]]])

# %%
arr1
# Out:
# array([[69, 57, 29, 45, 75],
#        [ 0,  1,  2,  3,  4]])

# %%
arr2=arr1[slice(0,1,1)]

# %%
arr2
# Out:
# array([[69, 57, 29, 45, 75]])

# %%
arr2[:]=0

# %%
arr2
# Out:
# array([[0, 0, 0, 0, 0]])

# %%
arr1
# Out:
# array([[0, 0, 0, 0, 0],
#        [0, 1, 2, 3, 4]])

# %%
del arr2

# %%
arr2=arr1[arr1==0]

# %%
arr2
# Out:
# array([0, 0, 0, 0, 0, 0])

# %%
arr2[:]=1

# %%
arr2
# Out:
# array([1, 1, 1, 1, 1, 1])

# %%
arr1
# Out:
# array([[0, 0, 0, 0, 0],
#        [0, 1, 2, 3, 4]])

# %%
arr
# Out:
# array([[[11, 22, 33, 44, 55],
#         [27,  5, 13, 52, 34],
#         [69, 57, 29, 45, 75],
#         [26, 58, 29,  2, 47]],
#
#        [[82, 36, 55, 86, 55],
#         [68, 72, 64, 54, 97],
#         [ 8, 25, 17, 85, 18],
#         [81,  5, 22, 15, 32]],
#
#        [[41,  6,  9, 51, 25],
#         [ 9, 98, 72, 45,  0],
#         [41, 15, 87, 63, 98],
#         [47, 48, 86, 52, 97]],
#
#        [[25, 71, 76, 48, 41],
#         [52,  1, 30, 30, 83],
#         [30, 64, 84, 44, 67],
#         [12,  2, 84, 71, 93]]])

# %%
arr[...,4]                               ## Last column from each dimension
# Out:
# array([[55, 34, 75, 47],
#        [55, 97, 18, 32],
#        [25,  0, 98, 97],
#        [41, 83, 67, 93]])

# %%
arr[0,...]                                 ## all the thing from 0 dimension
# Out:
# array([[11, 22, 33, 44, 55],
#        [27,  5, 13, 52, 34],
#        [69, 57, 29, 45, 75],
#        [26, 58, 29,  2, 47]])

# %%
arr[0,...,2:5]
# Out:
# array([[33, 44, 55],
#        [13, 52, 34],
#        [29, 45, 75],
#        [29,  2, 47]])

# %%
arr[np.newaxis,0,...,2:5]
# Out:
# array([[[33, 44, 55],
#         [13, 52, 34],
#         [29, 45, 75],
#         [29,  2, 47]]])

# %%
arr[0,...,2:5,np.newaxis]
# Out:
# array([[[33],
#         [44],
#         [55]],
#
#        [[13],
#         [52],
#         [34]],
#
#        [[29],
#         [45],
#         [75]],
#
#        [[29],
#         [ 2],
#         [47]]])

# %%
arr[0,...,np.newaxis,2:5]
# Out:
# array([[[33, 44, 55]],
#
#        [[13, 52, 34]],
#
#        [[29, 45, 75]],
#
#        [[29,  2, 47]]])
