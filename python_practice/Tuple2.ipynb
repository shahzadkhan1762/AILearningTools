# %%
T1=(1)

# %%
type(T1)
# Out:
# int

# %%
T1=('khan',)

# %%
type(T1)
# Out:
# tuple

# %%
T2=tuple('khan');

# %%
type(T2)
# Out:
# tuple

# %%
T1=(4,63,46,34,(4,3,6));

# %%
T1[-1][1]
# Out:
# 3

# %%
T1*1
# Out:
# (4, 63, 46, 34, (4, 3, 6))

# %%
T1*3
# Out:
# (4, 63, 46, 34, (4, 3, 6), 4, 63, 46, 34, (4, 3, 6), 4, 63, 46, 34, (4, 3, 6))

# %%
T3=(4,3,6,3,5)

# %%
T4=(4,6,2,7,7)

# %%
T1+T3
# Out:
# (4, 63, 46, 34, (4, 3, 6), 4, 3, 6, 3, 5)

# %%
len(T1)
# Out:
# 5

# %%
min(T4)
# Out:
# 2

# %%
min(T1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 min(T1)
#
# TypeError: '<' not supported between instances of 'tuple' and 'int'

# %%
sum(T1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 sum(T1)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
len(T1)
# Out:
# 5

# %%
sorted(T1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sorted(T1)
#
# TypeError: '<' not supported between instances of 'tuple' and 'int'

# %%
sorted(T4)
# Out:
# [2, 4, 6, 7, 7]

# %%
type(sorted(T4))
# Out:
# list
