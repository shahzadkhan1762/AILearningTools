# %% [markdown]
# ### Properties and Attributes of Numpy Array

# %% [markdown]
# #### shape

# %%
import numpy as np;

# %%
arr1=np.array([[[3,4],[8,6],[7,1]]]);

# %%
arr1
# Out:
# array([[[3, 4],
#         [8, 6],
#         [7, 1]]])

# %%
arr1.shape
# Out:
# (1, 3, 2)

# %%
arr1=np.array([[[3,5],[6,2]],[[5,2],[7,4]]]);

# %%
arr1
# Out:
# array([[[3, 5],
#         [6, 2]],
#
#        [[5, 2],
#         [7, 4]]])

# %%
arr1.shape
# Out:
# (2, 2, 2)

# %%
arr1.ndim
# Out:
# 3

# %%
arr1=np.array([[[3,5]],[[6,2]],[[9,3]]]);

# %%
arr1.shape
# Out:
# (3, 1, 2)

# %%
arr1=np.array([[[45],[65]],[[87],[26]]]);

# %%
arr1
# Out:
# array([[[45],
#         [65]],
#
#        [[87],
#         [26]]])

# %% [markdown]
# #### ndim

# %%
arr1.ndim
# Out:
# 3

# %% [markdown]
# #### size

# %%
arr1.size
# Out:
# 4

# %%
arr2=np.zeros((3,3));

# %%
arr2.size
# Out:
# 9

# %% [markdown]
# #### itemsize

# %%
arr1.itemsize
# Out:
# 4

# %%
arr2.itemsize
# Out:
# 8

# %% [markdown]
# #### dtype

# %%
arr1.dtype
# Out:
# dtype('int32')

# %%
arr2.dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### astype('')

# %%
arr1.dtype
# Out:
# dtype('int32')

# %%
arr1.astype('float')
# Out:
# array([[[45.],
#         [65.]],
#
#        [[87.],
#         [26.]]])

# %%
arr3=arr1.astype('float');

# %%
arr3
# Out:
# array([[[45.],
#         [65.]],
#
#        [[87.],
#         [26.]]])

# %%
arr3.dtype
# Out:
# dtype('float64')
