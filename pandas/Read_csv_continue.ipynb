# %%
import pandas as pd;
import numpy as np;

# %% [markdown]
# ## parsing
# - In computing, parsing typically refers to the analysis of textual data, often in the form of code or language syntax, to extract relevant information or convert it into a structured representation that can be used by a computer program.

# %% [markdown]
# ### parse_dates
# - bool, list of Hashable, list of lists or dict of {Hashablelist}, default False
#
# The behavior is as follows:
#
# - A boolean value:
#
#     - True: Pandas will attempt to parse all columns with datetime-like values as datetime objects.
#     - False (default): No datetime parsing will be performed.
#
# - list of int or names. e.g. If [1, 2, 3] -> try parsing columns 1, 2, 3 each as a separate date column.
#
# - list of list. e.g. If [[1, 3]] -> combine columns 1 and 3 and parse as a single date column.
#
# - dict, e.g. {'foo' : [1, 3]} -> parse columns 1, 3 as date and call result ‘foo’

# %%
df = pd.read_csv("Dates_time.csv");
df
# Out:
#   month_day_year day_month_year                 date_time year_month_day  \
# 0      4/22/1996      22-Apr-96  Tue Aug 11 09:50:35 1996      6/22/2007
# 1      4/23/1996      23-Apr-96  Tue May 12 19:50:35 2016       1/9/2017
# 2      5/14/1996      14-May-96  Mon Oct 14 09:50:35 2017      4/12/1998
# 3      5/15/1996      15-May-96  Tue Jan 11 09:50:35 2018      7/22/2027
# 4      5/16/2001      16-May-01  Fri Mar 11 07:30:36 2019     11/15/1945
# 5      5/17/2002      17-May-02  Tue Aug 11 09:50:35 2020      6/22/1942
# 6      5/18/2003      18-May-03  Wed Dec 21 09:50:35 2021     1887-06-13
# 7      5/19/2004      19-May-04  Tue Jan 11 09:50:35 2022      1/25/1912
# 8      5/20/2005      20-May-05  Sun Jul 10 19:40:25 2023      6/22/2007
#
#        Time
# 0   9:44:30
# 1  10:44:30
# 2  11:44:30
# 3  12:44:30
# 4  13:44:30
# 5  14:44:30
# 6  15:44:30
# 7  16:44:30
# 8  17:44:30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   month_day_year  9 non-null      object
#  1   day_month_year  9 non-null      object
#  2   date_time       9 non-null      object
#  3   year_month_day  9 non-null      object
#  4   Time            9 non-null      object
# dtypes: object(5)
# memory usage: 488.0+ bytes

# %%
df = pd.read_csv("Dates_time.csv", parse_dates=True)
df
# Out:
#   month_day_year day_month_year                 date_time year_month_day  \
# 0      4/22/1996      22-Apr-96  Tue Aug 11 09:50:35 1996      6/22/2007
# 1      4/23/1996      23-Apr-96  Tue May 12 19:50:35 2016       1/9/2017
# 2      5/14/1996      14-May-96  Mon Oct 14 09:50:35 2017      4/12/1998
# 3      5/15/1996      15-May-96  Tue Jan 11 09:50:35 2018      7/22/2027
# 4      5/16/2001      16-May-01  Fri Mar 11 07:30:36 2019     11/15/1945
# 5      5/17/2002      17-May-02  Tue Aug 11 09:50:35 2020      6/22/1942
# 6      5/18/2003      18-May-03  Wed Dec 21 09:50:35 2021     1887-06-13
# 7      5/19/2004      19-May-04  Tue Jan 11 09:50:35 2022      1/25/1912
# 8      5/20/2005      20-May-05  Sun Jul 10 19:40:25 2023      6/22/2007
#
#        Time
# 0   9:44:30
# 1  10:44:30
# 2  11:44:30
# 3  12:44:30
# 4  13:44:30
# 5  14:44:30
# 6  15:44:30
# 7  16:44:30
# 8  17:44:30

# %%
df.dtypes
# Out:
# month_day_year    object
# day_month_year    object
# date_time         object
# year_month_day    object
# Time              object
# dtype: object

# %%
df = pd.read_csv("Dates_time.csv", parse_dates=[0,1,2,3]);
df
# Out:
#   month_day_year day_month_year           date_time year_month_day      Time
# 0     1996-04-22     1996-04-22 1996-08-11 09:50:35     2007-06-22   9:44:30
# 1     1996-04-23     1996-04-23 2016-05-12 19:50:35     2017-01-09  10:44:30
# 2     1996-05-14     1996-05-14 2017-10-14 09:50:35     1998-04-12  11:44:30
# 3     1996-05-15     1996-05-15 2018-01-11 09:50:35     2027-07-22  12:44:30
# 4     2001-05-16     2001-05-16 2019-03-11 07:30:36     1945-11-15  13:44:30
# 5     2002-05-17     2002-05-17 2020-08-11 09:50:35     1942-06-22  14:44:30
# 6     2003-05-18     2003-05-18 2021-12-21 09:50:35     1887-06-13  15:44:30
# 7     2004-05-19     2004-05-19 2022-01-11 09:50:35     1912-01-25  16:44:30
# 8     2005-05-20     2005-05-20 2023-07-10 19:40:25     2007-06-22  17:44:30

# %%
df.dtypes
# Out:
# month_day_year    datetime64[ns]
# day_month_year    datetime64[ns]
# date_time         datetime64[ns]
# year_month_day    datetime64[ns]
# Time                      object
# dtype: object

# %%
df = pd.read_csv('Dates_time.csv', parse_dates=[[3,4]]);
df
# Out:
#   year_month_day_Time month_day_year day_month_year                 date_time
# 0 2007-06-22 09:44:30      4/22/1996      22-Apr-96  Tue Aug 11 09:50:35 1996
# 1 2017-01-09 10:44:30      4/23/1996      23-Apr-96  Tue May 12 19:50:35 2016
# 2 1998-04-12 11:44:30      5/14/1996      14-May-96  Mon Oct 14 09:50:35 2017
# 3 2027-07-22 12:44:30      5/15/1996      15-May-96  Tue Jan 11 09:50:35 2018
# 4 1945-11-15 13:44:30      5/16/2001      16-May-01  Fri Mar 11 07:30:36 2019
# 5 1942-06-22 14:44:30      5/17/2002      17-May-02  Tue Aug 11 09:50:35 2020
# 6 1887-06-13 15:44:30      5/18/2003      18-May-03  Wed Dec 21 09:50:35 2021
# 7 1912-01-25 16:44:30      5/19/2004      19-May-04  Tue Jan 11 09:50:35 2022
# 8 2007-06-22 17:44:30      5/20/2005      20-May-05  Sun Jul 10 19:40:25 2023

# %%
df.dtypes
# Out:
# year_month_day_Time    datetime64[ns]
# month_day_year                 object
# day_month_year                 object
# date_time                      object
# dtype: object

# %%
df = pd.read_csv('Dates_time.csv', parse_dates=['month_day_year', 'day_month_year', 'date_time']);
df
# Out:
#   month_day_year day_month_year           date_time year_month_day      Time
# 0     1996-04-22     1996-04-22 1996-08-11 09:50:35      6/22/2007   9:44:30
# 1     1996-04-23     1996-04-23 2016-05-12 19:50:35       1/9/2017  10:44:30
# 2     1996-05-14     1996-05-14 2017-10-14 09:50:35      4/12/1998  11:44:30
# 3     1996-05-15     1996-05-15 2018-01-11 09:50:35      7/22/2027  12:44:30
# 4     2001-05-16     2001-05-16 2019-03-11 07:30:36     11/15/1945  13:44:30
# 5     2002-05-17     2002-05-17 2020-08-11 09:50:35      6/22/1942  14:44:30
# 6     2003-05-18     2003-05-18 2021-12-21 09:50:35     1887-06-13  15:44:30
# 7     2004-05-19     2004-05-19 2022-01-11 09:50:35      1/25/1912  16:44:30
# 8     2005-05-20     2005-05-20 2023-07-10 19:40:25      6/22/2007  17:44:30

# %%
df.dtypes
# Out:
# month_day_year    datetime64[ns]
# day_month_year    datetime64[ns]
# date_time         datetime64[ns]
# year_month_day            object
# Time                      object
# dtype: object

# %%
df = pd.read_csv("Dates_time.csv", parse_dates={"MDYT":[0,4]});
df
# Out:
#                  MDYT day_month_year                 date_time year_month_day
# 0 1996-04-22 09:44:30      22-Apr-96  Tue Aug 11 09:50:35 1996      6/22/2007
# 1 1996-04-23 10:44:30      23-Apr-96  Tue May 12 19:50:35 2016       1/9/2017
# 2 1996-05-14 11:44:30      14-May-96  Mon Oct 14 09:50:35 2017      4/12/1998
# 3 1996-05-15 12:44:30      15-May-96  Tue Jan 11 09:50:35 2018      7/22/2027
# 4 2001-05-16 13:44:30      16-May-01  Fri Mar 11 07:30:36 2019     11/15/1945
# 5 2002-05-17 14:44:30      17-May-02  Tue Aug 11 09:50:35 2020      6/22/1942
# 6 2003-05-18 15:44:30      18-May-03  Wed Dec 21 09:50:35 2021     1887-06-13
# 7 2004-05-19 16:44:30      19-May-04  Tue Jan 11 09:50:35 2022      1/25/1912
# 8 2005-05-20 17:44:30      20-May-05  Sun Jul 10 19:40:25 2023      6/22/2007

# %%
df.dtypes
# Out:
# MDYT              datetime64[ns]
# day_month_year            object
# date_time                 object
# year_month_day            object
# dtype: object

# %%
df['MDYT'].dt.date
# Out:
# 0    1996-04-22
# 1    1996-04-23
# 2    1996-05-14
# 3    1996-05-15
# 4    2001-05-16
# 5    2002-05-17
# 6    2003-05-18
# 7    2004-05-19
# 8    2005-05-20
# Name: MDYT, dtype: object

# %%
df['MDYT'].dt.time
# Out:
# 0    09:44:30
# 1    10:44:30
# 2    11:44:30
# 3    12:44:30
# 4    13:44:30
# 5    14:44:30
# 6    15:44:30
# 7    16:44:30
# 8    17:44:30
# Name: MDYT, dtype: object

# %% [markdown]
# ### infer_datetime_format
# - bool, default False
# - used to control whether Pandas should attempt to automatically infer the datetime format of date and time columns while reading a CSV file.

# %%
df = pd.read_csv("Dates_time.csv", parse_dates=[0,1,2,3,4], infer_datetime_format=True);  
df
# Out:
#   month_day_year day_month_year           date_time year_month_day  \
# 0     1996-04-22     1996-04-22 1996-08-11 09:50:35     2007-06-22
# 1     1996-04-23     1996-04-23 2016-05-12 19:50:35     2017-01-09
# 2     1996-05-14     1996-05-14 2017-10-14 09:50:35     1998-04-12
# 3     1996-05-15     1996-05-15 2018-01-11 09:50:35     2027-07-22
# 4     2001-05-16     2001-05-16 2019-03-11 07:30:36     1945-11-15
# 5     2002-05-17     2002-05-17 2020-08-11 09:50:35     1942-06-22
# 6     2003-05-18     2003-05-18 2021-12-21 09:50:35     1887-06-13
# 7     2004-05-19     2004-05-19 2022-01-11 09:50:35     1912-01-25
# 8     2005-05-20     2005-05-20 2023-07-10 19:40:25     2007-06-22
#
#                  Time
# 0 2023-10-12 09:44:30
# 1 2023-10-12 10:44:30
# 2 2023-10-12 11:44:30
# 3 2023-10-12 12:44:30
# 4 2023-10-12 13:44:30
# 5 2023-10-12 14:44:30
# 6 2023-10-12 15:44:30
# 7 2023-10-12 16:44:30
# 8 2023-10-12 17:44:30

# %%
pd.read_csv("Dates_time.csv", parse_dates=[0,1,2,3,4])
# Out:
#   month_day_year day_month_year           date_time year_month_day  \
# 0     1996-04-22     1996-04-22 1996-08-11 09:50:35     2007-06-22
# 1     1996-04-23     1996-04-23 2016-05-12 19:50:35     2017-01-09
# 2     1996-05-14     1996-05-14 2017-10-14 09:50:35     1998-04-12
# 3     1996-05-15     1996-05-15 2018-01-11 09:50:35     2027-07-22
# 4     2001-05-16     2001-05-16 2019-03-11 07:30:36     1945-11-15
# 5     2002-05-17     2002-05-17 2020-08-11 09:50:35     1942-06-22
# 6     2003-05-18     2003-05-18 2021-12-21 09:50:35     1887-06-13
# 7     2004-05-19     2004-05-19 2022-01-11 09:50:35     1912-01-25
# 8     2005-05-20     2005-05-20 2023-07-10 19:40:25     2007-06-22
#
#                  Time
# 0 2023-10-12 09:44:30
# 1 2023-10-12 10:44:30
# 2 2023-10-12 11:44:30
# 3 2023-10-12 12:44:30
# 4 2023-10-12 13:44:30
# 5 2023-10-12 14:44:30
# 6 2023-10-12 15:44:30
# 7 2023-10-12 16:44:30
# 8 2023-10-12 17:44:30

# %% [markdown]
# ### keep_date_col
# - bool, default False
# - If True and parse_dates specifies combining multiple columns, then keep the original columns.

# %%
df = pd.read_csv("Dates_time.csv", parse_dates=[[0,4],0,1,2,3,4], infer_datetime_format=True, keep_date_col=True);
df
# Out:
#   month_day_year_Time month_day_year day_month_year           date_time  \
# 0 1996-04-22 09:44:30     1996-04-22     1996-04-22 1996-08-11 09:50:35
# 1 1996-04-23 10:44:30     1996-04-23     1996-04-23 2016-05-12 19:50:35
# 2 1996-05-14 11:44:30     1996-05-14     1996-05-14 2017-10-14 09:50:35
# 3 1996-05-15 12:44:30     1996-05-15     1996-05-15 2018-01-11 09:50:35
# 4 2001-05-16 13:44:30     2001-05-16     2001-05-16 2019-03-11 07:30:36
# 5 2002-05-17 14:44:30     2002-05-17     2002-05-17 2020-08-11 09:50:35
# 6 2003-05-18 15:44:30     2003-05-18     2003-05-18 2021-12-21 09:50:35
# 7 2004-05-19 16:44:30     2004-05-19     2004-05-19 2022-01-11 09:50:35
# 8 2005-05-20 17:44:30     2005-05-20     2005-05-20 2023-07-10 19:40:25
#
#   year_month_day                Time
# 0     2007-06-22 2023-10-12 09:44:30
# 1     2017-01-09 2023-10-12 10:44:30
# 2     1998-04-12 2023-10-12 11:44:30
# 3     2027-07-22 2023-10-12 12:44:30
# 4     1945-11-15 2023-10-12 13:44:30
# 5     1942-06-22 2023-10-12 14:44:30
# 6     1887-06-13 2023-10-12 15:44:30
# 7     1912-01-25 2023-10-12 16:44:30
# 8     2007-06-22 2023-10-12 17:44:30

# %%
df.dtypes
# Out:
# month_day_year_Time    datetime64[ns]
# month_day_year         datetime64[ns]
# day_month_year         datetime64[ns]
# date_time              datetime64[ns]
# year_month_day         datetime64[ns]
# Time                   datetime64[ns]
# dtype: object

# %%
df = pd.read_csv("Dates_time.csv", parse_dates={'DMYT':[1,4]}, keep_date_col=True);
df
# Out:
#                  DMYT month_day_year day_month_year                 date_time  \
# 0 1996-04-22 09:44:30      4/22/1996      22-Apr-96  Tue Aug 11 09:50:35 1996
# 1 1996-04-23 10:44:30      4/23/1996      23-Apr-96  Tue May 12 19:50:35 2016
# 2 1996-05-14 11:44:30      5/14/1996      14-May-96  Mon Oct 14 09:50:35 2017
# 3 1996-05-15 12:44:30      5/15/1996      15-May-96  Tue Jan 11 09:50:35 2018
# 4 2001-05-16 13:44:30      5/16/2001      16-May-01  Fri Mar 11 07:30:36 2019
# 5 2002-05-17 14:44:30      5/17/2002      17-May-02  Tue Aug 11 09:50:35 2020
# 6 2003-05-18 15:44:30      5/18/2003      18-May-03  Wed Dec 21 09:50:35 2021
# 7 2004-05-19 16:44:30      5/19/2004      19-May-04  Tue Jan 11 09:50:35 2022
# 8 2005-05-20 17:44:30      5/20/2005      20-May-05  Sun Jul 10 19:40:25 2023
#
#   year_month_day      Time
# 0      6/22/2007   9:44:30
# 1       1/9/2017  10:44:30
# 2      4/12/1998  11:44:30
# 3      7/22/2027  12:44:30
# 4     11/15/1945  13:44:30
# 5      6/22/1942  14:44:30
# 6     1887-06-13  15:44:30
# 7      1/25/1912  16:44:30
# 8      6/22/2007  17:44:30

# %%
df.dtypes
# Out:
# DMYT              datetime64[ns]
# month_day_year            object
# day_month_year            object
# date_time                 object
# year_month_day            object
# Time                      object
# dtype: object

# %%
df = pd.read_csv("Dates_time.csv", parse_dates={"DMYT":[1,4]}, keep_date_col=True);
df
# Out:
#                  DMYT month_day_year day_month_year                 date_time  \
# 0 1996-04-22 09:44:30      4/22/1996      22-Apr-96  Tue Aug 11 09:50:35 1996
# 1 1996-04-23 10:44:30      4/23/1996      23-Apr-96  Tue May 12 19:50:35 2016
# 2 1996-05-14 11:44:30      5/14/1996      14-May-96  Mon Oct 14 09:50:35 2017
# 3 1996-05-15 12:44:30      5/15/1996      15-May-96  Tue Jan 11 09:50:35 2018
# 4 2001-05-16 13:44:30      5/16/2001      16-May-01  Fri Mar 11 07:30:36 2019
# 5 2002-05-17 14:44:30      5/17/2002      17-May-02  Tue Aug 11 09:50:35 2020
# 6 2003-05-18 15:44:30      5/18/2003      18-May-03  Wed Dec 21 09:50:35 2021
# 7 2004-05-19 16:44:30      5/19/2004      19-May-04  Tue Jan 11 09:50:35 2022
# 8 2005-05-20 17:44:30      5/20/2005      20-May-05  Sun Jul 10 19:40:25 2023
#
#   year_month_day      Time
# 0      6/22/2007   9:44:30
# 1       1/9/2017  10:44:30
# 2      4/12/1998  11:44:30
# 3      7/22/2027  12:44:30
# 4     11/15/1945  13:44:30
# 5      6/22/1942  14:44:30
# 6     1887-06-13  15:44:30
# 7      1/25/1912  16:44:30
# 8      6/22/2007  17:44:30

# %% [markdown]
# ### date_parser
# - Callable, optional

# %%
df = pd.read_csv('Dates_time.csv', parse_dates=[0,1,2,3,4]);
df
# Out:
#   month_day_year day_month_year           date_time year_month_day  \
# 0     1996-04-22     1996-04-22 1996-08-11 09:50:35     2007-06-22
# 1     1996-04-23     1996-04-23 2016-05-12 19:50:35     2017-01-09
# 2     1996-05-14     1996-05-14 2017-10-14 09:50:35     1998-04-12
# 3     1996-05-15     1996-05-15 2018-01-11 09:50:35     2027-07-22
# 4     2001-05-16     2001-05-16 2019-03-11 07:30:36     1945-11-15
# 5     2002-05-17     2002-05-17 2020-08-11 09:50:35     1942-06-22
# 6     2003-05-18     2003-05-18 2021-12-21 09:50:35     1887-06-13
# 7     2004-05-19     2004-05-19 2022-01-11 09:50:35     1912-01-25
# 8     2005-05-20     2005-05-20 2023-07-10 19:40:25     2007-06-22
#
#                  Time
# 0 2023-10-13 09:44:30
# 1 2023-10-13 10:44:30
# 2 2023-10-13 11:44:30
# 3 2023-10-13 12:44:30
# 4 2023-10-13 13:44:30
# 5 2023-10-13 14:44:30
# 6 2023-10-13 15:44:30
# 7 2023-10-13 16:44:30
# 8 2023-10-13 17:44:30

# %%
df.dtypes
# Out:
# month_day_year    datetime64[ns]
# day_month_year    datetime64[ns]
# date_time         datetime64[ns]
# year_month_day    datetime64[ns]
# Time              datetime64[ns]
# dtype: object

# %%
# write your own parser to support a different date format, 
# for example, YYYY DD MM HH:MM:SS

from datetime import datetime

custom_date_parser = lambda x: datetime.strptime(x, "%m/%d/%Y")

df = pd.read_csv("Dates_time.csv", parse_dates=[0], date_parser=custom_date_parser);
df
# Out:
#   month_day_year day_month_year                 date_time year_month_day  \
# 0     1996-04-22      22-Apr-96  Tue Aug 11 09:50:35 1996      6/22/2007
# 1     1996-04-23      23-Apr-96  Tue May 12 19:50:35 2016       1/9/2017
# 2     1996-05-14      14-May-96  Mon Oct 14 09:50:35 2017      4/12/1998
# 3     1996-05-15      15-May-96  Tue Jan 11 09:50:35 2018      7/22/2027
# 4     2001-05-16      16-May-01  Fri Mar 11 07:30:36 2019     11/15/1945
# 5     2002-05-17      17-May-02  Tue Aug 11 09:50:35 2020      6/22/1942
# 6     2003-05-18      18-May-03  Wed Dec 21 09:50:35 2021     1887-06-13
# 7     2004-05-19      19-May-04  Tue Jan 11 09:50:35 2022      1/25/1912
# 8     2005-05-20      20-May-05  Sun Jul 10 19:40:25 2023      6/22/2007
#
#        Time
# 0   9:44:30
# 1  10:44:30
# 2  11:44:30
# 3  12:44:30
# 4  13:44:30
# 5  14:44:30
# 6  15:44:30
# 7  16:44:30
# 8  17:44:30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   month_day_year  9 non-null      datetime64[ns]
#  1   day_month_year  9 non-null      object
#  2   date_time       9 non-null      object
#  3   year_month_day  9 non-null      object
#  4   Time            9 non-null      object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 488.0+ bytes

# %% [markdown]
# ### date_format
# - str or dict of column -> format, optional
# - New in version 2.0.0.

# %%
# df = pd.read_csv("Dates_time.csv", parse_dates=[0], date_format="%d-%m-%Y");
# df

# %% [markdown]
# ### dayfirst
# - bool, default False
# - DD/MM format dates, international and European format.

# %%
df = pd.read_csv("Dates_time.csv", parse_dates=[0], dayfirst=True);
df
# Out:
# C:\Users\ABBAS\AppData\Local\Temp\ipykernel_6924\4100200662.py:1: UserWarning: Parsing dates in MM/DD/YYYY format when dayfirst=True was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df = pd.read_csv("Dates_time.csv", parse_dates=[0], dayfirst=True);
#   month_day_year day_month_year                 date_time year_month_day  \
# 0     1996-04-22      22-Apr-96  Tue Aug 11 09:50:35 1996      6/22/2007
# 1     1996-04-23      23-Apr-96  Tue May 12 19:50:35 2016       1/9/2017
# 2     1996-05-14      14-May-96  Mon Oct 14 09:50:35 2017      4/12/1998
# 3     1996-05-15      15-May-96  Tue Jan 11 09:50:35 2018      7/22/2027
# 4     2001-05-16      16-May-01  Fri Mar 11 07:30:36 2019     11/15/1945
# 5     2002-05-17      17-May-02  Tue Aug 11 09:50:35 2020      6/22/1942
# 6     2003-05-18      18-May-03  Wed Dec 21 09:50:35 2021     1887-06-13
# 7     2004-05-19      19-May-04  Tue Jan 11 09:50:35 2022      1/25/1912
# 8     2005-05-20      20-May-05  Sun Jul 10 19:40:25 2023      6/22/2007
#
#        Time
# 0   9:44:30
# 1  10:44:30
# 2  11:44:30
# 3  12:44:30
# 4  13:44:30
# 5  14:44:30
# 6  15:44:30
# 7  16:44:30
# 8  17:44:30

# %%
custom_date_parser = lambda date: pd.to_datetime(date, dayfirst=True);

df = pd.read_csv("Dates_time.csv", parse_dates=[0], date_parser=custom_date_parser);
df
# Out:
# C:\Users\ABBAS\AppData\Local\Temp\ipykernel_6924\4261797633.py:1: UserWarning: Parsing dates in MM/DD/YYYY format when dayfirst=True was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   custom_date_parser = lambda date: pd.to_datetime(date, dayfirst=True);
#   month_day_year day_month_year                 date_time year_month_day  \
# 0     1996-04-22      22-Apr-96  Tue Aug 11 09:50:35 1996      6/22/2007
# 1     1996-04-23      23-Apr-96  Tue May 12 19:50:35 2016       1/9/2017
# 2     1996-05-14      14-May-96  Mon Oct 14 09:50:35 2017      4/12/1998
# 3     1996-05-15      15-May-96  Tue Jan 11 09:50:35 2018      7/22/2027
# 4     2001-05-16      16-May-01  Fri Mar 11 07:30:36 2019     11/15/1945
# 5     2002-05-17      17-May-02  Tue Aug 11 09:50:35 2020      6/22/1942
# 6     2003-05-18      18-May-03  Wed Dec 21 09:50:35 2021     1887-06-13
# 7     2004-05-19      19-May-04  Tue Jan 11 09:50:35 2022      1/25/1912
# 8     2005-05-20      20-May-05  Sun Jul 10 19:40:25 2023      6/22/2007
#
#        Time
# 0   9:44:30
# 1  10:44:30
# 2  11:44:30
# 3  12:44:30
# 4  13:44:30
# 5  14:44:30
# 6  15:44:30
# 7  16:44:30
# 8  17:44:30

# %%
custom_date_parser = lambda x: datetime.strptime(x, "%m/%d/%Y")

df = pd.read_csv("Dates_time.csv", parse_dates=[0], date_parser=custom_date_parser, dayfirst=True);
df
# Out:
#   month_day_year day_month_year                 date_time year_month_day  \
# 0     1996-04-22      22-Apr-96  Tue Aug 11 09:50:35 1996      6/22/2007
# 1     1996-04-23      23-Apr-96  Tue May 12 19:50:35 2016       1/9/2017
# 2     1996-05-14      14-May-96  Mon Oct 14 09:50:35 2017      4/12/1998
# 3     1996-05-15      15-May-96  Tue Jan 11 09:50:35 2018      7/22/2027
# 4     2001-05-16      16-May-01  Fri Mar 11 07:30:36 2019     11/15/1945
# 5     2002-05-17      17-May-02  Tue Aug 11 09:50:35 2020      6/22/1942
# 6     2003-05-18      18-May-03  Wed Dec 21 09:50:35 2021     1887-06-13
# 7     2004-05-19      19-May-04  Tue Jan 11 09:50:35 2022      1/25/1912
# 8     2005-05-20      20-May-05  Sun Jul 10 19:40:25 2023      6/22/2007
#
#        Time
# 0   9:44:30
# 1  10:44:30
# 2  11:44:30
# 3  12:44:30
# 4  13:44:30
# 5  14:44:30
# 6  15:44:30
# 7  16:44:30
# 8  17:44:30

# %%
custom_date_parser = lambda x: datetime.strptime(x, "%m/%d/%Y")

df = pd.read_csv("Dates_time.csv", parse_dates=[3], date_parser=custom_date_parser, dayfirst=True, infer_datetime_format=True);
df
# Out:
#   month_day_year day_month_year                 date_time year_month_day  \
# 0      4/22/1996      22-Apr-96  Tue Aug 11 09:50:35 1996     2007-06-22
# 1      4/23/1996      23-Apr-96  Tue May 12 19:50:35 2016     2017-01-09
# 2      5/14/1996      14-May-96  Mon Oct 14 09:50:35 2017     1998-04-12
# 3      5/15/1996      15-May-96  Tue Jan 11 09:50:35 2018     2027-07-22
# 4      5/16/2001      16-May-01  Fri Mar 11 07:30:36 2019     1945-11-15
# 5      5/17/2002      17-May-02  Tue Aug 11 09:50:35 2020     1942-06-22
# 6      5/18/2003      18-May-03  Wed Dec 21 09:50:35 2021     1887-06-13
# 7      5/19/2004      19-May-04  Tue Jan 11 09:50:35 2022     1912-01-25
# 8      5/20/2005      20-May-05  Sun Jul 10 19:40:25 2023     2007-06-22
#
#        Time
# 0   9:44:30
# 1  10:44:30
# 2  11:44:30
# 3  12:44:30
# 4  13:44:30
# 5  14:44:30
# 6  15:44:30
# 7  16:44:30
# 8  17:44:30

# %% [markdown]
# ### iterator
# - bool, default False
# - Return TextFileReader object for iteration or getting chunks with get_chunk().

# %%
file = pd.read_csv("Employee.csv", iterator=True);
file

# %%
df = file.get_chunk()

# %%
df
# Out:
#     Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0   Bachelors         2017          ,            3   34    Male          No
# 1   Bachelors         2013       Pune            1   28  Female         NaN
# 2        Null         2014        NaN            3   38     NaN          No
# 3     Masters         2016  Bangalore            3   27    Male          No
# 4     Masters         2017       Pune            3   24     NaN         Yes
# ..        ...          ...        ...          ...  ...     ...         ...
# 94  Bachelors         2014  Bangalore            3   39    Male          No
# 95        PHD         2018  Bangalore            3   26    Male          No
# 96  Bachelors         2016  Bangalore            3   31  Female          No
# 97  Bachelors         2014  Bangalore            3   27    Male          No
# 98  Bachelors         2014        NaN            3   29  Female          No
#
#     ExperienceInCurrentDomain  LeaveOrNot
# 0                           0         0.0
# 1                           3         1.0
# 2                           2         0.0
# 3                           5         1.0
# 4                           2         1.0
# ..                        ...         ...
# 94                          3         1.0
# 95                          4         1.0
# 96                          0         0.0
# 97                          5         1.0
# 98                          0         0.0
#
# [99 rows x 9 columns]

# %%
reader = pd.read_csv("Employee.csv", iterator=True);

df = reader.get_chunk(20);
df
# Out:
#     Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0   Bachelors         2017          ,            3   34    Male          No
# 1   Bachelors         2013       Pune            1   28  Female         NaN
# 2        Null         2014        NaN            3   38     NaN          No
# 3     Masters         2016  Bangalore            3   27    Male          No
# 4     Masters         2017       Pune            3   24     NaN         Yes
# 5   Bachelors         2016  Bangalore            3   22    Male          No
# 6   Bachelors         2015        NaN            3   38    Male          No
# 7         NaN         2016  Bangalore            3   34  Female          No
# 8   Bachelors         2016       Pune            3   23     NaN          No
# 9     Masters         2017  New Delhi            2   37    Male          No
# 10    Masters         2012  Bangalore            3   27    Male          No
# 11  Bachelors         2016       Pune            3   34    Male          No
# 12  Bachelors         2018       Pune            3   32    Male         Yes
# 13  Bachelors         2016  Bangalore            3   39    Male          No
# 14  Bachelors         2012        NaN            3   37    Male          No
# 15  Bachelors         2017  Bangalore            1   29    Male          No
# 16  Bachelors         2014  Bangalore            3   34  Female          No
# 17  Bachelors         2014       Pune            3   34    Male          No
# 18  Bachelors         2015       Pune            2   30  Female          No
# 19  Bachelors         2016  New Delhi            2   22  Female          No
#
#     ExperienceInCurrentDomain  LeaveOrNot
# 0                           0         0.0
# 1                           3         1.0
# 2                           2         0.0
# 3                           5         1.0
# 4                           2         1.0
# 5                           0         NaN
# 6                           0         0.0
# 7                           2         1.0
# 8                           1         0.0
# 9                           2         0.0
# 10                          5         1.0
# 11                          3         0.0
# 12                          5         1.0
# 13                          2         NaN
# 14                          4         0.0
# 15                          3         0.0
# 16                          2         0.0
# 17                          4         0.0
# 18                          0         1.0
# 19                          0         1.0

# %% [markdown]
# ### chunksize
# - int, optional
# - Number of lines to read from the file per chunk.

# %%
file = pd.read_csv('Employee.csv', chunksize=20);
file

# %%
df = file.get_chunk();

# %%
df
# Out:
#     Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0   Bachelors         2017          ,            3   34    Male          No
# 1   Bachelors         2013       Pune            1   28  Female         NaN
# 2        Null         2014        NaN            3   38     NaN          No
# 3     Masters         2016  Bangalore            3   27    Male          No
# 4     Masters         2017       Pune            3   24     NaN         Yes
# 5   Bachelors         2016  Bangalore            3   22    Male          No
# 6   Bachelors         2015        NaN            3   38    Male          No
# 7         NaN         2016  Bangalore            3   34  Female          No
# 8   Bachelors         2016       Pune            3   23     NaN          No
# 9     Masters         2017  New Delhi            2   37    Male          No
# 10    Masters         2012  Bangalore            3   27    Male          No
# 11  Bachelors         2016       Pune            3   34    Male          No
# 12  Bachelors         2018       Pune            3   32    Male         Yes
# 13  Bachelors         2016  Bangalore            3   39    Male          No
# 14  Bachelors         2012        NaN            3   37    Male          No
# 15  Bachelors         2017  Bangalore            1   29    Male          No
# 16  Bachelors         2014  Bangalore            3   34  Female          No
# 17  Bachelors         2014       Pune            3   34    Male          No
# 18  Bachelors         2015       Pune            2   30  Female          No
# 19  Bachelors         2016  New Delhi            2   22  Female          No
#
#     ExperienceInCurrentDomain  LeaveOrNot
# 0                           0         0.0
# 1                           3         1.0
# 2                           2         0.0
# 3                           5         1.0
# 4                           2         1.0
# 5                           0         NaN
# 6                           0         0.0
# 7                           2         1.0
# 8                           1         0.0
# 9                           2         0.0
# 10                          5         1.0
# 11                          3         0.0
# 12                          5         1.0
# 13                          2         NaN
# 14                          4         0.0
# 15                          3         0.0
# 16                          2         0.0
# 17                          4         0.0
# 18                          0         1.0
# 19                          0         1.0

# %%
df = file.get_chunk()
df
# Out:
#     Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 20  Bachelors         2012  Bangalore            3   37    Male          No
# 21    Masters         2017  New Delhi            2   28    Male          No
# 22  Bachelors         2017  New Delhi            2   36    Male          No
# 23  Bachelors         2015  Bangalore            3   27    Male         Yes
# 24  Bachelors         2017  Bangalore            3   29    Male          No
# 25  Bachelors         2013  Bangalore            3   22  Female         Yes
# 26  Bachelors         2016  Bangalore            3   37    Male          No
# 27  Bachelors         2015  Bangalore            3   23    Male          No
# 28  Bachelors         2013       Pune            2   31  Female          No
# 29    Masters         2017  New Delhi            2   30  Female          No
# 30        PHD         2013  New Delhi            3   25    Male          No
# 31  Bachelors         2014  Bangalore            3   23    Male          No
# 32  Bachelors         2018  Bangalore            3   26    Male          No
# 33  Bachelors         2016  Bangalore            3   40    Male          No
# 34  Bachelors         2017       Pune            2   37  Female          No
# 35  Bachelors         2014  Bangalore            1   30  Female          No
# 36  Bachelors         2012  New Delhi            3   29    Male          No
# 37        NaN         2018  New Delhi            2   34  Female          No
# 38  Bachelors         2017       Pune            2   29  Female          No
# 39  Bachelors         2014       Pune            3   30    Male         Yes
#
#     ExperienceInCurrentDomain  LeaveOrNot
# 20                          0           0
# 21                          4           0
# 22                          3           0
# 23                          5           0
# 24                          4           0
# 25                          0           0
# 26                          2           0
# 27                          1           0
# 28                          2           1
# 29                          2           0
# 30                          3           0
# 31                          1           0
# 32                          4           1
# 33                          5           0
# 34                          0           1
# 35                          3           0
# 36                          3           0
# 37                          0           1
# 38                          2           1
# 39                          4           0

# %%
df = file.get_chunk()
df
# Out:
#     Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 40  Bachelors         2015  Bangalore            3   36    Male          No
# 41    Masters         2017  New Delhi            2   23    Male          No
# 42  Bachelors         2013  Bangalore            3   30    Male          No
# 43  Bachelors         2014  Bangalore            3   36    Male          No
# 44  Bachelors         2015       Pune            3   39    Male          No
# 45  Bachelors         2014  Bangalore            3   23  Female          No
# 46        PHD         2012  New Delhi            3   27    Male          No
# 47    Masters         2013  New Delhi            3   35    Male          No
# 48    Masters         2017  New Delhi            2   34    Male          No
# 49  Bachelors         2013  Bangalore            3   30  Female          No
# 50        PHD         2017  New Delhi            3   34    Male          No
# 51  Bachelors         2015       Pune            2   26  Female          No
# 52  Bachelors         2016  Bangalore            3   34  Female          No
# 53  Bachelors         2014  Bangalore            3   31  Female         Yes
# 54  Bachelors         2017  New Delhi            3   31  Female         Yes
# 55        PHD         2013  New Delhi            3   28    Male          No
# 56  Bachelors         2016  Bangalore            3   38    Male          No
# 57    Masters         2014       Pune            3   39  Female          No
# 58  Bachelors         2013       Pune            3   32    Male          No
# 59    Masters         2017       Pune            2   36    Male          No
#
#     ExperienceInCurrentDomain  LeaveOrNot
# 40                          1           0
# 41                          1           0
# 42                          3           1
# 43                          0           0
# 44                          4           0
# 45                          1           0
# 46                          5           0
# 47                          2           0
# 48                          0           0
# 49                          1           0
# 50                          2           0
# 51                          4           1
# 52                          0           0
# 53                          5           0
# 54                          5           0
# 55                          2           0
# 56                          2           0
# 57                          2           0
# 58                          4           0
# 59                          2           1

# %% [markdown]
# ### thousands
# - str (length 1), optional
# - Character acting as the thousands separator in numerical values.

# %%
df = pd.read_csv("Numbers.txt", parse_dates=[2]);
df
# Out:
#        Name  Age  hire_date        Salary
# 0     Akram   22 2020-04-22     50-000-00
# 1     Usman   20 2004-05-23   2-340-000-0
# 2     Sajid   21 2006-08-15  34-000-000-0
# 3    Kaleem   23 2010-01-29  23-000-000-0
# 4  Mudassir   19 2019-12-22     2-000-000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      int64
#  2   hire_date  5 non-null      datetime64[ns]
#  3   Salary     5 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 288.0+ bytes

# %%
df=pd.read_csv("Numbers.txt", parse_dates=[2], thousands='-');
df
# Out:
#        Name  Age  hire_date     Salary
# 0     Akram   22 2020-04-22    5000000
# 1     Usman   20 2004-05-23   23400000
# 2     Sajid   21 2006-08-15  340000000
# 3    Kaleem   23 2010-01-29  230000000
# 4  Mudassir   19 2019-12-22    2000000

# %%
df.dtypes
# Out:
# Name                 object
# Age                   int64
# hire_date    datetime64[ns]
# Salary                int64
# dtype: object

# %% [markdown]
# ### decimal
# - str (length 1), default ‘.’
# - Character to recognize as decimal point (e.g., use ‘,’ for European data).

# %%
df = pd.read_csv("Numbers.txt", parse_dates=[2], decimal='\'');
df
# Out:
#        Name  Age  hire_date        Salary  Bonus
# 0     Akram   22 2020-04-22     50-000-00    2.3
# 1     Usman   20 2004-05-23   2-340-000-0    5.1
# 2     Sajid   21 2006-08-15  34-000-000-0    6.1
# 3    Kaleem   23 2010-01-29  23-000-000-0    2.5
# 4  Mudassir   19 2019-12-22     2-000-000    6.0

# %%
df = pd.read_csv("Numbers.txt", parse_dates=[2], decimal='\'', thousands='-');
df
# Out:
#        Name  Age  hire_date     Salary  Bonus
# 0     Akram   22 2020-04-22    5000000    2.3
# 1     Usman   20 2004-05-23   23400000    5.1
# 2     Sajid   21 2006-08-15  340000000    6.1
# 3    Kaleem   23 2010-01-29  230000000    2.5
# 4  Mudassir   19 2019-12-22    2000000    6.0

# %% [markdown]
# ### lineterminator
# - str (length 1), optional
# - Character used to denote a line break. Only valid with C parser.

# %%
from io import StringIO

# %%
data = """Name,age,gpa! Abbas,20,3.0! Kausar,22,3.5! Usman,21,3.6""";

df = pd.read_csv(StringIO(data), lineterminator='!', engine='c');
df
# Out:
#       Name  age  gpa
# 0    Abbas   20  3.0
# 1   Kausar   22  3.5
# 2    Usman   21  3.6

# %% [markdown]
# ### quotechar
# - str (length 1), optional
# - Character used to denote the start and end of a quoted item. Quoted items can include the delimiter and it will be ignored.

# %%
data = """Name,age,gpa!/Muhammad Abbas/,20,3.0! Kausar,22,3.5! Usman,21,3.6""";

df = pd.read_csv(StringIO(data), lineterminator='!', quotechar='/');
df
# Out:
#              Name  age  gpa
# 0  Muhammad Abbas   20  3.0
# 1          Kausar   22  3.5
# 2           Usman   21  3.6

# %% [markdown]
# ### quoting{0 or csv.QUOTE_MINIMAL, 1 or csv.QUOTE_ALL, 2 or csv.QUOTE_NONNUMERIC, 3 or csv.QUOTE_NONE}, default csv.QUOTE_MINIMAL

# %%
import csv

# %%
data = """Name,age,gpa!/Muhammad Abbas/,20,3.0! /Kausar/,22,3.5! Usman,21,3.6""";

df = pd.read_csv(StringIO(data), lineterminator='!', quotechar='/');
df
# Out:
#              Name  age  gpa
# 0  Muhammad Abbas   20  3.0
# 1        /Kausar/   22  3.5
# 2           Usman   21  3.6

# %%
data = """Name,age,gpa!"Muhammad Abbas",20,3.0! "Kausar",22,3.5! Usman,21,3.6""";

df = pd.read_csv(StringIO(data), lineterminator='!', quotechar='"', quoting=csv.QUOTE_ALL);
df
# Out:
#              Name  age  gpa
# 0  Muhammad Abbas   20  3.0
# 1        "Kausar"   22  3.5
# 2           Usman   21  3.6

# %%
data = """Name,age,gpa!"Muhammad Abbas",20,3.0! "Kausar",22,3.5! Usman,21,3.6""";

df = pd.read_csv(StringIO(data), lineterminator='!', quotechar='"', quoting=csv.QUOTE_NONNUMERIC);
df
# Out:
#              Name   age  gpa
# 0  Muhammad Abbas  20.0  3.0
# 1        "Kausar"  22.0  3.5
# 2           Usman  21.0  3.6

# %%
data = """Name,age,gpa!"Muhammad Abbas",20,3.0! "Kausar",22,3.5! Usman,21,3.6""";

df = pd.read_csv(StringIO(data), lineterminator='!', quotechar='"', quoting=csv.QUOTE_NONE);
df
# Out:
#                Name  age  gpa
# 0  "Muhammad Abbas"   20  3.0
# 1          "Kausar"   22  3.5
# 2             Usman   21  3.6

# %% [markdown]
# ### doublequote
# - bool, default True
# - When quotechar is specified and quoting is not QUOTE_NONE, indicate whether or not to interpret two consecutive quotechar elements INSIDE a field as a single quotechar element.

# %%
data = 'Name,age,gpa!"Muhammad Abbas""khan""",20,3.0! "Kausar",22,3.5! Usman,21,3.6';

df = pd.read_csv(StringIO(data), lineterminator='!', quotechar='"', quoting=csv.QUOTE_ALL, doublequote=True);
df
# Out:
#                    Name  age  gpa
# 0  Muhammad Abbas"khan"   20  3.0
# 1              "Kausar"   22  3.5
# 2                 Usman   21  3.6

# %%
data = 'Name,age,gpa!"Muhammad Abbas""khan""",20,3.0! "Kausar",22,3.5! Usman,21,3.6';

df = pd.read_csv(StringIO(data), lineterminator='!', quotechar='"', quoting=csv.QUOTE_ALL, doublequote=False);
df
# Out:
#                      Name  age  gpa
# 0  Muhammad Abbas"khan"""   20  3.0
# 1                "Kausar"   22  3.5
# 2                   Usman   21  3.6

# %% [markdown]
# ### escapechar
# - str (length 1), optional
# - Character used to escape other characters.

# %%
data = 'Name,age,gpa!"Muhammad|" Abbas",20,3.0! Kausar,22,3.5! Usman,21,3.6';

df = pd.read_csv(StringIO(data), lineterminator='!', quoting=csv.QUOTE_ALL, quotechar='"', escapechar='|');
df
# Out:
#               Name  age  gpa
# 0  Muhammad" Abbas   20  3.0
# 1           Kausar   22  3.5
# 2            Usman   21  3.6

# %% [markdown]
# ### comment
# - str (length 1), optional

# %%
data = 'Name,age,gpa!"Muhammad|" Abbas|"",20,3.0! Kausar,22,3.5 #Usman,21,3.6';

df = pd.read_csv(StringIO(data), lineterminator='!', quoting=csv.QUOTE_ALL, quotechar='"', escapechar='|', skipinitialspace=True, comment='#');
df
# Out:
#                Name  age  gpa
# 0  Muhammad" Abbas"   20  3.0
# 1            Kausar   22  3.5
