# %% [markdown]
# #### ZeroDivisionError

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
num1=int(input("Enter first number : "));
num2=int(input("Enter secord number : "));

try:
    division=num1/num2;
    print(f"The Division of {num1} and {num2} is : ",division);
except ZeroDivisionError:
    print("Can't Divide By Zero!");
# Out:
# Enter first number : 6
# Enter secord number : 4
# The Division of 6 and 4 is :  1.5

# %% [markdown]
# #### Handling the FileNotFoundError Exception

# %%
file_path='abbas.txt';
with open(file_path) as file_object:
    contents=file_object.read();
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 file_path='abbas.txt';
# ----> 2 with open(file_path) as file_object:
#       3     contents=file_object.read()
#
# File D:\Installed_Programs\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abbas.txt'

# %%
try:
    with open(file_path) as file_object:
        content=file_object.read();
except FileNotFoundError:
    print("Sorry! the "+file_path+" file does't exist.");
# Out:
# Sorry! the abbas.txt file does't exist.
