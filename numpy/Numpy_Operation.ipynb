# %% [markdown]
# ### Basic Operation on Numpy Array

# %%
import numpy as np;

# %%
arr1=np.array([4,5,2,6,4,7,3]);

# %%
arr2=np.array([6,9,3,5,8,3,7]);

# %%
arr1-arr2
# Out:
# array([-2, -4, -1,  1, -4,  4, -4])

# %%
arr1+arr2
# Out:
# array([10, 14,  5, 11, 12, 10, 10])

# %%
arr1*arr2
# Out:
# array([24, 45,  6, 30, 32, 21, 21])

# %%
arr3=np.array([5,3,7,3]);

# %%
arr1*arr3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 arr1*arr3
#
# ValueError: operands could not be broadcast together with shapes (7,) (4,)

# %%
arr1
# Out:
# array([4, 5, 2, 6, 4, 7, 3])

# %%
3*arr1
# Out:
# array([12, 15,  6, 18, 12, 21,  9])

# %%
arr1*3
# Out:
# array([12, 15,  6, 18, 12, 21,  9])

# %%
arr1>5
# Out:
# array([False, False, False,  True, False,  True, False])

# %% [markdown]
# #### dot()

# %%
arr3=np.arange(6).reshape(2,3);

# %%
arr3
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
arr4=np.arange(6,12).reshape(3,2);

# %%
arr4
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %%
arr3.dot(arr4)
# Out:
# array([[ 28,  31],
#        [100, 112]])

# %%
arr1
# Out:
# array([4, 5, 2, 6, 4, 7, 3])

# %%
arr2
# Out:
# array([6, 9, 3, 5, 8, 3, 7])

# %%
arr1.max()
# Out:
# 7

# %%
arr2.min()
# Out:
# 3

# %%
arr1.min()
# Out:
# 2

# %%
arr3
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
arr4
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %%
arr3.min(axis=0)
# Out:
# array([0, 1, 2])

# %%
arr4.max(axis=1)
# Out:
# array([ 7,  9, 11])

# %%
arr3.sum()
# Out:
# 15

# %%
arr4.sum()
# Out:
# 51

# %%
arr3.sum(axis=1)
# Out:
# array([ 3, 12])

# %%
arr3.mean()
# Out:
# 2.5

# %%
arr4.mean(axis=0)
# Out:
# array([8., 9.])

# %%
np.median(arr3)
# Out:
# 2.5

# %%
arr3.std()
# Out:
# 1.707825127659933

# %%
np.sin(arr3)
# Out:
# array([[ 0.        ,  0.84147098,  0.90929743],
#        [ 0.14112001, -0.7568025 , -0.95892427]])

# %%
np.exp(arr4)
# Out:
# array([[  403.42879349,  1096.63315843],
#        [ 2980.95798704,  8103.08392758],
#        [22026.46579481, 59874.1417152 ]])
