# %%
import numpy as np;

# %%
x=np.array([[2.,5.],[8.,3.]]);
x
# Out:
# array([[2., 5.],
#        [8., 3.]])

# %%
x.T
# Out:
# array([[2., 8.],
#        [5., 3.]])

# %%
x.T
# Out:
# array([[2., 8.],
#        [5., 3.]])

# %%
x
# Out:
# array([[2., 5.],
#        [8., 3.]])

# %%
print(id(x))
# Out:
# 1952543232080

# %%
x=x.T

# %%
x
# Out:
# array([[2., 8.],
#        [5., 3.]])

# %%
print(id(x))
# Out:
# 1952543231600

# %%
x=np.array([1.,2.,4.,5.,6.])

# %%
x
# Out:
# array([1., 2., 4., 5., 6.])

# %%
x.T
# Out:
# array([1., 2., 4., 5., 6.])

# %%
x.data

# %%
x.dtype
# Out:
# dtype('float64')

# %%
type(x.dtype)
# Out:
# numpy.dtype[float64]
