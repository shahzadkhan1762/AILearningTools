# %% [markdown]
# ## String in Python

# %% [markdown]
# - Python string is the collection of the characters surrounded by single quotes, double quotes, or triple quotes.

# %%
c='hello';
print(c);
# Out:
# hello

# %%
"it's raining outside"
# Out:
# "it's raining outside"

# %%
c[3]
# Out:
# 'l'

# %%
print(c[4]);
# Out:
# o

# %%
len(c)
# Out:
# 5

# %%
c="""this is a string 
in truple inverted quomas"""

# %%
c
# Out:
# 'this is a string \nin truple inverted quomas'

# %%
c="Hello"

# %%
for i in range(5):
    print(c[i]);
# Out:
# H
# e
# l
# l
# o

# %%
for i in range(-5,0):
    print(c[i])
# Out:
# H
# e
# l
# l
# o

# %%
for i in range(1,6):
    print(c[-i])
# Out:
# o
# l
# l
# e
# H

# %%
for i in c:
    print(i)
# Out:
# H
# e
# l
# l
# o

# %%
for i in c[::-1]:
    print(i)
# Out:
# o
# l
# l
# e
# H

# %%
c
# Out:
# 'Hello'

# %%
c[-2]
# Out:
# 'l'

# %%
c="Hello World!";

# %%
print(c[6:])
# Out:
# World!

# %%
print(c[0:8:3])
# Out:
# HlW

# %%
print(c[0::3])
# Out:
# HlWl

# %%
print(c[::-1])
# Out:
# !dlroW olleH

# %%
print(c[-1:-7:-1])
# Out:
# !dlroW

# %%
print(c[-8::-1])
# Out:
# olleH

# %%
del c;

# %%
c="hello"

# %%
c
# Out:
# 'hello'

# %%
"Hello"+"world"
# Out:
# 'Helloworld'

# %%
"Hello"+" "+"world"
# Out:
# 'Hello world'

# %%
"*"*10
# Out:
# '**********'

# %%
for i in range(5):
    for j in range(i):
        print('*'*3,end='')
    print();
# Out:
# ***
# ******
# *********
# ************

# %%
"Hello"=="world"
# Out:
# False

# %%
"Hello"=="Hello"
# Out:
# True

# %%
"Hello"=="hello"
# Out:
# False

# %%
"Hello".lower()=="hello"
# Out:
# True

# %%
"Hello"<"world"
# Out:
# True

# %%
""<"Hello"
# Out:
# True

# %%
"Hello" and "world"
# Out:
# 'world'

# %%
'Hello'>'abbas'
# Out:
# False

# %%
"" and "Hello"
# Out:
# ''

# %%
"" or "Hello"
# Out:
# 'Hello'

# %%
not "hello"
# Out:
# False

# %%
not ""
# Out:
# True

# %%
c
# Out:
# 'hello'

# %%
'l' in c
# Out:
# True

# %%
"H" in c
# Out:
# False

# %%
'H' not in c
# Out:
# True

# %%
'h' not in c
# Out:
# False

# %%
c="islamabad";

# %%
len(c)
# Out:
# 9

# %%
max(c)
# Out:
# 's'

# %%
min(c)
# Out:
# 'a'

# %%
sorted(c)
# Out:
# ['a', 'a', 'a', 'b', 'd', 'i', 'l', 'm', 's']

# %%
sorted(c, reverse=True)
# Out:
# ['s', 'm', 'l', 'i', 'd', 'b', 'a', 'a', 'a']

# %% [markdown]
# #### Find / index

# %%
'pakistan'.find('k')
# Out:
# 2

# %%
'pakistan'.index('k')
# Out:
# 2

# %%
'pakistan'.find('o')
# Out:
# -1

# %%
'pakistan'.index('o')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 'pakistan'.index('o')
#
# ValueError: substring not found

# %% [markdown]
# #### title()

# %%
c.title()
# Out:
# 'Islamabad'

# %% [markdown]
# #### capitalize()
# ***capitalize function capitalize the first character of string***

# %%
c.capitalize()
# Out:
# 'Islamabad'

# %%
"this is capitalize string".capitalize()
# Out:
# 'This is capitalize string'

# %% [markdown]
# #### lower()

# %%
c.lower()
# Out:
# 'islamabad'

# %%
"ABBAS".lower()
# Out:
# 'abbas'

# %% [markdown]
# #### upper()

# %%
c.upper()
# Out:
# 'ISLAMABAD'

# %%
c='i am in islamabad'

# %%
c.capitalize()
# Out:
# 'I am in islamabad'

# %%
c.title()
# Out:
# 'I Am In Islamabad'

# %% [markdown]
# #### swapcase()

# %%
c.swapcase()
# Out:
# 'I AM IN ISLAMABAD'

# %%
c="Hello World"

# %%
c.swapcase()
# Out:
# 'hELLO wORLD'

# %% [markdown]
# #### count()

# %%
c.count('o')
# Out:
# 2

# %%
c.count('World')
# Out:
# 1

# %%
c.count('world')
# Out:
# 0

# %%
string='pakistan'
string.count('k')
# Out:
# 1

# %% [markdown]
# #### endswith() / startswith()

# %%
'pakistan'.endswith('an')
# Out:
# True

# %%
'this is called beauti of hangu'.endswith('hangu')
# Out:
# True

# %%
'this is called beauti of hangu'.endswith('kohat')
# Out:
# False

# %%
'this is called beauti of hangu'.startswith('hangu')
# Out:
# False

# %%
'this is called beauti of hangu'.startswith('this')
# Out:
# True

# %% [markdown]
# #### format()

# %%
"my name is {} and my age is {}".format('abbas',20)
# Out:
# 'my name is abbas and my age is 20'

# %%
"my name is {1} and my age is {0}".format('abbas',20)
# Out:
# 'my name is 20 and my age is abbas'

# %%
"my name is {name} and my age is {age} and my department is {dept}".format(name='abbas',age=20,dept='SE')
# Out:
# 'my name is abbas and my age is 20 and my department is SE'

# %%
"my name is {name} and my age is {age}".format(name='abbas',age=20,dept='SE')
# Out:
# 'my name is abbas and my age is 20'

# %% [markdown]
# #### isalnum()  isalpha()  isdecimal()  isdigit()  isidentifier()

# %%
"khan".isalnum()
# Out:
# True

# %%
"Khan#".isalnum()
# Out:
# False

# %%
'34'.isdigit()
# Out:
# True

# %%
"34d".isdigit()
# Out:
# False

# %%
"hello world".isidentifier()
# Out:
# False

# %%
"hello_world".isidentifier()
# Out:
# True

# %% [markdown]
# #### split()

# %%
'h e l l o'.split()
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
"hello".split()
# Out:
# ['hello']

# %% [markdown]
# #### join()

# %%
' '.join(['h','e','l','l','o'])
# Out:
# 'h e l l o'

# %%
'-'.join(['khan','khan','khan','khan'])
# Out:
# 'khan-khan-khan-khan'

# %% [markdown]
# #### replace()

# %%
'i like pakistan'.replace('like','love')
# Out:
# 'i love pakistan'

# %% [markdown]
# #### Strip()

# %%
sample='how are you';
words=sample.split();
result=[];
for word in words:
    result.append(word.capitalize())
    
tit=' '.join(result);
tit
# Out:
# 'How Are You'
