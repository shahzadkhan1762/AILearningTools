# %% [markdown]
# ### Variable

# %% [markdown]
# * Variables are containers for storing data values.

# %%
# Syntax
a=43;
print(a);
# Out:
# 43

# %%
a=45;b=74;c=95;
print(a);
print(b);
print(c);
# Out:
# 45
# 74
# 95

# %%
a,b,c=84,36,59;
print(a);
print(b);
print(c);
# Out:
# 84
# 36
# 59

# %% [markdown]
# ### Kaywords

# %% [markdown]
# - In programmming, a keywords is a word that is reserved by a program because the word has a special meaning. Keywords can be commands or parameters. Every programming language has a set of keywords that cannot be used a variable names.

# %%
# Python has 33 keywords
import keyword
print(keyword.kwlist);
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### Identifiers

# %% [markdown]
# A Python identifier is a name used to identify a variable,function,class,module or other object.

# %% [markdown]
# #### Rules for Identifier

# %% [markdown]
# - Variable names can contain only letters, numbers, and underscores.
# - Spaces are not allowed in variable names, but underscores can be used
#      to separate words in variable names.
# - Avoid using Python keywords and function names as variable names;
# - Variable names should be short but descriptive.
# - Be careful when using the lowercase letter l and the uppercase letter O
#      because they could be confused with the numbers 1 and 0.

# %% [markdown]
# Examples

# %%
st_No=34;
# st-No=34;    Error

# %%
first name='waleed';    # Error Because spaces are not allowed
# Out:
#   Cell In[12], line 1
#     first name='waleed';
#           ^
# SyntaxError: invalid syntax

# %%
if = 4.5;             # Error Because if is a keyword
# Out:
#   Cell In[17], line 1
#     if = 4.5;             # Error Because if is a keyword
#        ^
# SyntaxError: invalid syntax
