# %% [markdown]
# ## Tuple in Python

# %%
Tuple=(34,'hamid','hangu','pakistan');

# %%
Tuple1=();

# %%
Tuple2=('peshawar','karachi','kohat','bannu','karak');

# %%
print(Tuple);
# Out:
# (34, 'hamid', 'hangu', 'pakistan')

# %%
print(Tuple2);
# Out:
# ('peshawar', 'karachi', 'kohat', 'bannu', 'karak')

# %%
print(Tuple1);
# Out:
# ()

# %%
print(Tuple2[:]);
# Out:
# ('peshawar', 'karachi', 'kohat', 'bannu', 'karak')

# %%
print(Tuple2[:-3]);
# Out:
# ('peshawar', 'karachi')

# %%
Tuple3=Tuple[:2];

# %%
print(Tuple3);
# Out:
# (34, 'hamid')

# %%
print(Tuple3[0]);
# Out:
# 34

# %%
NestTuple=((434,634,634,634),(545,344,256,234));

# %%
print(NestTuple[0][0]);
print(NestTuple[0][1]);
print(NestTuple[0][2]);
print(NestTuple[0][3]);
# Out:
# 434
# 634
# 634
# 634

# %%
try:
    print(NestTuple([0][4]));
except Exception as e:
    print(e);
# Out:
# list index out of range

# %%
Tuple;

# %%
print(Tuple);
# Out:
# (34, 'hamid', 'hangu', 'pakistan')

# %%
print(Tuple1)
# Out:
# ()

# %%
print(Tuple2)
# Out:
# ('peshawar', 'karachi', 'kohat', 'bannu', 'karak')

# %%
print(Tuple3)
# Out:
# (34, 'hamid')

# %%
Tuple[0]=53;
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 Tuple[0]=53
#
# TypeError: 'tuple' object does not support item assignment

# %%
Tuple1=Tuple+Tuple3;

# %%
print(Tuple1);
# Out:
# (34, 'hamid', 'hangu', 'pakistan', 34, 'hamid')

# %%
for item in Tuple2:
    print(item);
# Out:
# peshawar
# karachi
# kohat
# bannu
# karak
