# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.factorial(4)
# Out:
# 24

# %%
math.ceil(4.5)
# Out:
# 5

# %%
math.floor(4.5)
# Out:
# 4

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
import random

# %%
random.randint(1,100)
# Out:
# 77

# %%
a=[1,2,3,4,5,6,7]
random.shuffle(a)
a
# Out:
# [4, 2, 5, 1, 7, 6, 3]

# %%
import time

# %%
time.time()
# Out:
# 1689942509.059602

# %%
time.ctime()
# Out:
# 'Fri Jul 21 17:28:41 2023'

# %%
print("Hello")
time.sleep(1)
print("world")
# Out:
# Hello
# world

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ABBAS\\Desktop\\JupyterPython'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Arbitrary_Argument.ipynb',
#  'arrayCreation.ipynb',
#  'arrayOperation.ipynb',
#  'break-continue-and-pass.ipynb',
#  'Built_in_Functions.ipynb',
#  'chatGPTQuestion.ipynb',
#  'circleArea.ipynb',
#  'CodeHarry.ipynb',
#  'common_element_list.ipynb',
#  'difference_Function_for_set.ipynb',
#  'factorial.html',
#  'factorial.ipynb',
#  'FizzBuzz.ipynb',
#  'forLoop.ipynb',
#  'Function.ipynb',
#  'google_exercises.ipynb',
#  'Guessing_Game.ipynb',
#  'list_comprehensions.ipynb',
#  'modules.ipynb',
#  'Nested_Function.ipynb',
#  'npArray.ipynb',
#  'Pair_Sum.ipynb',
#  'Palindrome_Check.ipynb',
#  'previligesUserClass.ipynb',
#  'primeNumber.ipynb',
#  'pyClasses.ipynb',
#  'pythonDoc1.ipynb',
#  'pythonDoc2.ipynb',
#  'restaurantClass.ipynb',
#  'sets.ipynb',
#  'String100.ipynb',
#  'Task_without_Feature_Extactor.ipynb',
#  'Task_with_HOG.ipynb',
#  'Task_with_ORB.ipynb',
#  'Task_with_SIFT.ipynb',
#  'tuple.ipynb',
#  'Tuple2.ipynb',
# ...
