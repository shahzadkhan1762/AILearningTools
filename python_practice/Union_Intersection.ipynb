# %%
def union_intersection(set1,set2):
    union=set1.union(set2);
    intersection=set1.intersection(set2);
    return union,intersection;

# %%
set1={2,3,4,5,6,7};
set2={6,7,9,10,20};
union_intersection(set1,set2)
# Out:
# ({2, 3, 4, 5, 6, 7, 9, 10, 20}, {6, 7})

# %%
union,intersection=union_intersection(set1,set2);
print("the Union is : ",union);
print("the intersection is : ",intersection);
# Out:
# the Union is :  {2, 3, 4, 5, 6, 7, 9, 10, 20}
# the intersection is :  {6, 7}
