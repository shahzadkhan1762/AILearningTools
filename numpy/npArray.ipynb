# %%
import numpy as np

# %%
arr=np.array([4,6,2,62,5]);

# %%
print(arr);
# Out:
# [ 4  6  2 62  5]

# %%
for i in arr:
    print(i);
# Out:
# 4
# 6
# 2
# 62
# 5

# %%
arr.shape
# Out:
# (5,)

# %%
arr.size
# Out:
# 5

# %%
print(arr.max)
# Out:
# <built-in method max of numpy.ndarray object at 0x000001A6B690C030>

# %%
print(arr.max());
# Out:
# 62

# %%
print(arr.min());
# Out:
# 2

# %%
print(arr.argmax());
# Out:
# 3

# %%
print(arr);
# Out:
# [ 4  6  2 62  5]

# %%
print(arr.dtype)
# Out:
# int32

# %% [markdown]
# ### N Dimensional Array

# %%
ndArray=np.array([[53,63,73,73],[34,63,83,83]],np.int32);

# %%
print(ndArray)
# Out:
# [[53 63 73 73]
#  [34 63 83 83]]

# %%
print(ndArray[0][0]);
# Out:
# 53

# %%
print(ndArray[1][3]);
# Out:
# 83

# %%
print(type(ndArray));
# Out:
# <class 'numpy.ndarray'>

# %%
print(ndArray.dtype);
# Out:
# int32

# %%
print(ndArray.shape)
# Out:
# (2, 4)

# %%
print(ndArray.size);
# Out:
# 8

# %%
for i in range(2):
    for j in range(4):
        print(ndArray[i][j],end=' ');
        j+=1;
    print();
    i+=1;
# Out:
# 53 63 73 73
# 34 63 83 83

# %%
i=0;
j=0;
print(ndArray[i][j]);
# Out:
# 53

# %%
ndSlice=ndArray[:1];

# %%
print(ndSlice);
# Out:
# [[53 63 73 73]]

# %%
print(ndSlice.shape);
# Out:
# (1, 4)

# %%
ndSlice[0][0]=10;

# %%
print(ndSlice[0][0]);
# Out:
# 10

# %%
print(ndArray[0][0]);
# Out:
# 10
