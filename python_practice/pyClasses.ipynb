# %% [markdown]
# ## Classes in python

# %%
class Restaurant():
    """ class to  represent a Restaurant """
    
    def __init__(self,restaurant_name, cuisine_type):
        self.restaurant_name=restaurant_name;
        self.cuisine_type=cuisine_type;
        
    def describe_res(self):
        print("The name of restaurant is : "+self.restaurant_name);
        print("Restaurant type is : "+self.cuisine_type);
        
    def open_res(self):
        print(self.restaurant_name+" is open.");

# %%
restaurant = Restaurant("KFC","Fast Food");

# %%
print(restaurant.restaurant_name);
# Out:
# KFC

# %%
print(restaurant.cuisine_type)
# Out:
# Fast Food

# %%
restaurant.describe_res();
# Out:
# The name of restaurant is : KFC
# Restaurant type is : Fast Food

# %%
restaurant.open_res();
# Out:
# KFC is open.

# %%
restaurant2=Restaurant("Islamia Restaurant","Breakfast Lunch Dinner");

# %%
print(restaurant2)

# %%
print(restaurant2.restaurant_name)
# Out:
# Islamia Restaurant

# %%
print(restaurant2.cuisine_type)
# Out:
# Breakfast Lunch Dinner

# %%
restaurant2.describe_res();
# Out:
# The name of restaurant is : Islamia Restaurant
# Restaurant type is : Breakfast Lunch Dinner

# %%
restaurant2.open_res();
# Out:
# Islamia Restaurant is open.
