# %%
s=u"\U0001f600";
print(s)
# Out:
# 😀

# %%
print(u"\U0001f500");
# Out:
# 🔀

# %%
print(u"\U0001f703")
# Out:
# 🜃

# %%
print(u"\U0001f100")
# Out:
# 🄀

# %%
print(u"\U0001f430")
# Out:
# 🐰

# %%
print(u"\U0001f610")
# Out:
# 😐

# %%
print(u"\U0001f601")
# Out:
# 😁

# %%
print(u"\U0001f602")
# Out:
# 😂

# %%
print(u"\U0001f603")
# Out:
# 😃

# %%
print(u"\U0001f604")
# Out:
# 😄

# %%
print(u"\U0001f605")
# Out:
# 😅

# %%
print(u"\U0001f691")
# Out:
# 🚑

# %%
print(u"\U0001f680")
# Out:
# 🚀

# %%
print(u"\U0001f918")
# Out:
# 🤘

# %%
print(u"\U0001f44E")
# Out:
# 👎

# %%
print(u"\U0001f44C")
# Out:
# 👌

# %%
print(u"\U0001f44F")
# Out:
# 👏

# %%
print(u"\U0001f44A")
# Out:
# 👊

# %%
print(u"\U0001f44B")
# Out:
# 👋

# %%
print(u"\U0001f200")
# Out:
# 🈀

# %%
print(u"\U0001f231")
# Out:
# 🈱

# %%
print(u"\U0001f603")
# Out:
# 😃

# %%
print(1.3e-4)
# Out:
# 0.00013

# %%
print(3e10)
# Out:
# 30000000000.0

# %%
print(True+2)
# Out:
# 3

# %%
print(233.33)
# Out:
# 233.33

# %%
print(3.4e-4)
# Out:
# 0.00034

# %%
print(r'\n this is a raw string\n\t')
# Out:
# \n this is a raw string\n\t
