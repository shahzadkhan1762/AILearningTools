# %% [markdown]
# ### Function inside Function

# %%
def f():
    print("inside f");
    
    def g():
        print("inside g");
    
    g();

# %%
f();
# Out:
# inside f
# inside g

# %%
def ftn():
    
    def p(n1,n2):
        return n1**n2;
    
    return p;

# %%
print(ftn()(3,3));
# Out:
# 27
